# %% [markdown]
# # Bengali.AI fastai2 starter
# I decided to start working with fastai2, after a few hours of searching the notebooks and documentation I finnaly got to this point. I figured this may be helpfull to other people wanting to learn about the new fastai version so I'm sharing this notebook. Let me know if you find anything that can be improved, I'm just getting started with fastai2!
#
# Some references:
# * https://www.kaggle.com/yiheng/iterative-stratification
# * https://www.kaggle.com/iafoss/image-preprocessing-128x128
# * https://www.kaggle.com/iafoss/grapheme-fast-ai-starter-lb-0-964
# * https://github.com/fastai/fastai2
# * http://dev.fast.ai/
#
# Versions log:
# * **Version 4:** fastai2 starter code; LB0.9598
# * **Version 5:** Updated to fastai2 v0.07; Added MixUp

# %%
pip install torchcontrib
# Out:
# Collecting torchcontrib
#   Downloading torchcontrib-0.0.2.tar.gz (11 kB)
# Building wheels for collected packages: torchcontrib
#   Building wheel for torchcontrib (setup.py) ... done
#   Created wheel for torchcontrib: filename=torchcontrib-0.0.2-py3-none-any.whl size=7532 sha256=ceaabfed5c956414123fe1a0e3d0fa63ea25dc057e3fdd07ae87e0c6875140c1
#   Stored in directory: /home/lam/.cache/pip/wheels/91/58/d0/f03811c3e34e1f14031294b5f30d8693689972af874d1225b8
# Successfully built torchcontrib
# Installing collected packages: torchcontrib
# Successfully installed torchcontrib-0.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Clone and install fastai2
#!git clone https://github.com/fastai/fastai2 lib
#!pip install -e lib
#!ln -s lib/fastai2 fastai2
# !pip install scikit-learn fastai2 --upgrade
# Out:
# Requirement already up-to-date: scikit-learn in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (0.22.1)
# Collecting fastai2
#   Using cached fastai2-0.0.7-py3-none-any.whl (170 kB)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from scikit-learn) (0.14.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from scikit-learn) (1.4.1)
# Collecting torch<1.4.0,>=1.2.0
#   Using cached torch-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (734.6 MB)
# Collecting spacy
#   Downloading spacy-2.2.3-cp37-cp37m-manylinux1_x86_64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 8.5 MB/s eta 0:00:01
# Collecting fastcore
#   Using cached fastcore-0.1.10-py3-none-any.whl (27 kB)
# Requirement already satisfied, skipping upgrade: torchvision<=0.4.2 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (0.3.0)
# Requirement already satisfied, skipping upgrade: matplotlib in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (3.1.1)
# Collecting pyyaml
#   Downloading PyYAML-5.3.tar.gz (268 kB)
#      |████████████████████████████████| 268 kB 25.1 MB/s eta 0:00:01
# Collecting requests
#   Using cached requests-2.22.0-py2.py3-none-any.whl (57 kB)
# Collecting fastprogress>=0.1.22
#   Using cached fastprogress-0.2.2-py3-none-any.whl (12 kB)
# Requirement already satisfied, skipping upgrade: pillow in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (6.1.0)
# Requirement already satisfied, skipping upgrade: pandas in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (0.25.3)
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.6.0-py3-none-any.whl (20 kB)
# Collecting blis<0.5.0,>=0.4.0
#   Using cached blis-0.4.1-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (19 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.2-cp37-cp37m-manylinux1_x86_64.whl (118 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Using cached plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.3-cp37-cp37m-manylinux1_x86_64.whl (32 kB)
# Collecting srsly<1.1.0,>=0.1.0
#   Downloading srsly-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (185 kB)
#      |████████████████████████████████| 185 kB 13.4 MB/s eta 0:00:01
# Collecting thinc<7.4.0,>=7.3.0
#   Using cached thinc-7.3.1-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
# Requirement already satisfied, skipping upgrade: setuptools in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (45.1.0.post20200127)
# Requirement already satisfied, skipping upgrade: six in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from torchvision<=0.4.2->fastai2) (1.14.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from matplotlib->fastai2) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from matplotlib->fastai2) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from matplotlib->fastai2) (2.4.6)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from matplotlib->fastai2) (2.8.1)
# Collecting chardet<3.1.0,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 21.7 MB/s eta 0:00:01
# Collecting idna<2.9,>=2.5
#   Using cached idna-2.8-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from requests->fastai2) (2019.11.28)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from pandas->fastai2) (2019.3)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from catalogue<1.1.0,>=0.0.7->spacy->fastai2) (1.5.0)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.10.0 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from thinc<7.4.0,>=7.3.0->spacy->fastai2) (4.41.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy->fastai2) (2.1.0)
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3-cp37-cp37m-linux_x86_64.whl size=44228 sha256=54dc26e5f73b7310dbdd4988d5ff528927cfeba439ec900b4f47ce41c1cbc17a
#   Stored in directory: /home/lam/.cache/pip/wheels/8a/55/a4/c0a81d27c33462cfdcb904db018f5550197e88b2b6b85beed2
# Successfully built pyyaml
# Installing collected packages: torch, wasabi, blis, catalogue, murmurhash, cymem, preshed, plac, srsly, thinc, chardet, urllib3, idna, requests, spacy, fastcore, pyyaml, fastprogress, fastai2
#   Attempting uninstall: torch
#     Found existing installation: torch 1.1.0
#     Uninstalling torch-1.1.0:
#       Successfully uninstalled torch-1.1.0
# Successfully installed blis-0.4.1 catalogue-1.0.0 chardet-3.0.4 cymem-2.0.3 fastai2-0.0.7 fastcore-0.1.10 fastprogress-0.2.2 idna-2.8 murmurhash-1.0.2 plac-1.1.3 preshed-3.0.2 pyyaml-5.3 requests-2.22.0 spacy-2.2.3 srsly-1.0.1 thinc-7.3.1 torch-1.3.1 urllib3-1.25.8 wasabi-0.6.0

# %%
# !pip install fastai2 fastai --upgrade
# Out:
# Requirement already up-to-date: fastai2 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (0.0.7)
# Collecting fastai
#   Using cached fastai-1.0.60-py3-none-any.whl (237 kB)
# Requirement already satisfied, skipping upgrade: fastcore in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (0.1.10)
# Requirement already satisfied, skipping upgrade: torch<1.4.0,>=1.2.0 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (1.3.1)
# Requirement already satisfied, skipping upgrade: spacy in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (2.2.3)
# Requirement already satisfied, skipping upgrade: pandas in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (0.25.3)
# Requirement already satisfied, skipping upgrade: requests in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (2.22.0)
# Requirement already satisfied, skipping upgrade: fastprogress>=0.1.22 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (0.2.2)
# Requirement already satisfied, skipping upgrade: pillow in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (6.1.0)
# Requirement already satisfied, skipping upgrade: matplotlib in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (3.1.1)
# Requirement already satisfied, skipping upgrade: scipy in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (1.4.1)
# Requirement already satisfied, skipping upgrade: scikit-learn in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (0.22.1)
# Requirement already satisfied, skipping upgrade: torchvision<=0.4.2 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (0.3.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai2) (5.3)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 8.4 MB/s eta 0:00:01
# Collecting bottleneck
#   Downloading Bottleneck-1.3.1.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 1.5 MB/s  eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Processing /home/lam/.cache/pip/wheels/e4/1d/06/640c93f5270d67d0247f30be91f232700d19023f9e66d735c7/nvidia_ml_py3-7.352.0-cp37-none-any.whl
# Collecting packaging
#   Downloading packaging-20.1-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from fastai) (1.18.1)
# Collecting numexpr
#   Downloading numexpr-2.7.1-cp37-cp37m-manylinux1_x86_64.whl (162 kB)
#      |████████████████████████████████| 162 kB 45.2 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (2.0.3)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (3.0.2)
# Requirement already satisfied, skipping upgrade: setuptools in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (45.1.0.post20200127)
# Requirement already satisfied, skipping upgrade: blis<0.5.0,>=0.4.0 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (0.4.1)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (0.6.0)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=0.1.0 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (1.0.1)
# Requirement already satisfied, skipping upgrade: thinc<7.4.0,>=7.3.0 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (7.3.1)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (1.1.3)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (1.0.0)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from spacy->fastai2) (1.0.2)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from pandas->fastai2) (2019.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from pandas->fastai2) (2.8.1)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from requests->fastai2) (2019.11.28)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from requests->fastai2) (1.25.8)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from requests->fastai2) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from requests->fastai2) (3.0.4)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from matplotlib->fastai2) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from matplotlib->fastai2) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from matplotlib->fastai2) (2.4.6)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from scikit-learn->fastai2) (0.14.1)
# Requirement already satisfied, skipping upgrade: six in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from torchvision<=0.4.2->fastai2) (1.14.0)
# Collecting soupsieve>=1.2
#   Downloading soupsieve-1.9.5-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.10.0 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from thinc<7.4.0,>=7.3.0->spacy->fastai2) (4.41.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from catalogue<1.1.0,>=0.0.7->spacy->fastai2) (1.5.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/lam/anaconda3/envs/hugo/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy->fastai2) (2.1.0)
# Building wheels for collected packages: bottleneck
#   Building wheel for bottleneck (PEP 517) ... done
#   Created wheel for bottleneck: filename=Bottleneck-1.3.1-cp37-cp37m-linux_x86_64.whl size=319618 sha256=13a4f1784aebd9297718b07172f243ff2437e0f5ad94910b44e3af07b49edb72
#   Stored in directory: /home/lam/.cache/pip/wheels/ce/98/7a/a671db4f462674db2299adc3ab78fda69a3421e6703fac37fa
# Successfully built bottleneck
# Installing collected packages: soupsieve, beautifulsoup4, bottleneck, nvidia-ml-py3, packaging, numexpr, fastai
# Successfully installed beautifulsoup4-4.8.2 bottleneck-1.3.1 fastai-1.0.60 numexpr-2.7.1 nvidia-ml-py3-7.352.0 packaging-20.1 soupsieve-1.9.5

# %%
import fastai2
from fastai2.vision.all import *
from sklearn.metrics import recall_score
print(fastai2.__version__)
# Out:
# 0.0.7

# %%
# Configs
sz = 128
bs = 128
nfolds = 5
fold = 0
TRAIN = Path('../data/grapheme-imgs-128x128')
LABELS = Path('../data/iterative-stratification/train_with_fold.csv')
arch = xresnet50

# %%
# Load dataframe
df = pd.read_csv(LABELS)
df.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme  id  \
# 0  Train_0             15                9                    5   ক্ট্রো   0
# 1  Train_1            159                0                    0        হ   1
# 2  Train_2             22                3                    5     খ্রী   2
# 3  Train_3             53                2                    2     র্টি   3
# 4  Train_4             71                9                    5     থ্রো   4
#
#    fold
# 0     3
# 1     2
# 2     4
# 3     2
# 4     1

# %%
# Create databunch
bengali = DataBlock(blocks=(ImageBlock(cls=PILImageBW), *(3*[CategoryBlock])),
                    getters=[ColReader('image_id', pref=TRAIN, suff='.png'),   # input
                             ColReader('grapheme_root'),                       # label 1
                             ColReader('vowel_diacritic'),                     # label 2
                             ColReader('consonant_diacritic')],                # label 3
                    splitter=IndexSplitter(df.loc[df.fold==fold].index))

tfms = aug_transforms(do_flip=False, size=sz)
tfms += [Normalize.from_stats([0.0692], [0.2051])]
dls = bengali.dataloaders(df, bs=bs, batch_tfms=tfms)
dls.n_inp = 1 # number of inputs

# %%
# Show an example
dls.show_batch(max_n=1, figsize=(3,3))

# %%
# Model 
class Head(Module):
    def __init__(self, nc, n, ps=0.5):
        self.fc = nn.Sequential(*[AdaptiveConcatPool2d(), nn.ReLU(inplace=True), Flatten(),
             LinBnDrop(nc*2, 512, True, ps, nn.ReLU(inplace=True)),
             LinBnDrop(512, n, True, ps)])
        self._init_weight()
        
    def _init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1.0)
                m.bias.data.zero_()
        
    def forward(self, x):
        return self.fc(x)

class BengaliModel(Module):
    def __init__(self, arch=arch, n=dls.c, pre=True):
        m = arch(pre)
        m = nn.Sequential(*children_and_parameters(m)[:-4])
        conv = nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1, bias=False)
        w = (m[0][0].weight.sum(1)).unsqueeze(1)
        conv.weight = nn.Parameter(w)
        m[0][0] = conv
        nc = m(torch.zeros(2, 1, sz, sz)).detach().shape[1]
        self.body = m
        self.heads = nn.ModuleList([Head(nc, c) for c in n])
        
    def forward(self, x):    
        x = self.body(x)
        return [f(x) for f in self.heads]

# %%
# Loss function
class Loss_combine(Module):
    def __init__(self, func=F.cross_entropy, weights=[2, 1, 1]):
        self.func, self.w = func, weights

    def forward(self, xs, *ys, reduction='mean'):
        for i, w, x, y in zip(range(len(xs)), self.w, xs, ys):
            if i == 0: loss = w*self.func(x, y, reduction=reduction) 
            else: loss += w*self.func(x, y, reduction=reduction) 
        return loss

# %%
# Metrics
class RecallPartial(Metric):
    # based on AccumMetric
    "Stores predictions and targets on CPU in accumulate to perform final calculations with `func`."
    def __init__(self, a=0, **kwargs):
        self.func = partial(recall_score, average='macro', zero_division=0)
        self.a = a

    def reset(self): self.targs,self.preds = [],[]

    def accumulate(self, learn):
        pred = learn.pred[self.a].argmax(dim=-1)
        targ = learn.y[self.a]
        pred,targ = to_detach(pred),to_detach(targ)
        pred,targ = flatten_check(pred,targ)
        self.preds.append(pred)
        self.targs.append(targ)

    @property
    def value(self):
        if len(self.preds) == 0: return
        preds,targs = torch.cat(self.preds),torch.cat(self.targs)
        return self.func(targs, preds)

    @property
    def name(self): return df.columns[self.a+1]
    
class RecallCombine(Metric):
    def accumulate(self, learn):
        scores = [learn.metrics[i].value for i in range(3)]
        self.combine = np.average(scores, weights=[2,1,1])

    @property
    def value(self):
        return self.combine

# %%
# MixUp
from torch.distributions.beta import Beta
def NoLoss(*o): pass
class MixUp(Callback):
    run_after,run_valid = [Normalize],False
    def __init__(self, alpha=0.4): 
        self.distrib = Beta(tensor(alpha), tensor(alpha))
        
    def begin_fit(self):
        self.loss_func0 = self.learn.loss_func
        
    def begin_batch(self):
        self.learn.loss_func = NoLoss
        lam = self.distrib.sample((self.y[0].size(0),)).squeeze().to(self.x[0].device)
        lam = torch.stack([lam, 1-lam], 1)
        self.lam = lam.max(1)[0]
        shuffle = torch.randperm(self.y[0].size(0)).to(self.x.device)
        xb1 = tuple(L(self.xb).itemgot(shuffle))
        yb1 = tuple([self.yb[i][shuffle] for i in range(len(self.yb))])
        nx_dims = len(self.x.size())
        self.learn.xb = tuple(L(xb1,self.xb).map_zip(torch.lerp,weight=unsqueeze(self.lam, n=nx_dims-1)))
        self.learn.yb = yb1,self.yb
        
    def after_loss(self):
        loss0 = self.loss_func0(self.learn.pred, *self.learn.yb[0], reduction='none')
        loss1 = self.loss_func0(self.learn.pred, *self.learn.yb[1], reduction='none')
        self.learn.loss = torch.lerp(loss0, loss1, self.lam).mean()
        self.learn.loss_func = self.loss_func0

# %%
opt.bn_update(train_loader, model)

# %%
opt = torchcontrib.optim.SWA(base_opt)
for i in range(100):
    opt.zero_grad()
    loss_fn(model(input), target).backward()
    opt.step()
    if i > 10 and i % 5 == 0:
        opt.update_swa()
opt.swap_swa_sgd()

# %%
SWA(base_opt, swa_start, swa_freq, swa_lr)

# %%
# training loop
base_opt = torch.optim.SGD(model.parameters(), lr=0.1)
opt = torchcontrib.optim.SWA(base_opt, swa_start=10, swa_freq=5, swa_lr=0.05)
for _ in range(100):
     opt.zero_grad()
     loss_fn(model(input), target).backward()
     opt.step()
opt.swap_swa_sgd()

# %%
# Create learner
learn = Learner(dls, BengaliModel(), loss_func=Loss_combine(), cbs=[MixUp(), CSVLogger()],
                metrics=[RecallPartial(a=i) for i in range(len(dls.c))] + [RecallCombine()],
                splitter=lambda m: [list(m.body.parameters()), list(m.heads.parameters())])
# Out:
# Downloading: "https://s3.amazonaws.com/fast-ai-modelzoo/xrn50_940.pth" to /home/lam/.cache/torch/checkpoints/xrn50_940.pth
# 100%|██████████| 244M/244M [02:12<00:00, 1.93MB/s]

# %%
learn.fit_one_cycle(36, lr_max=slice(1e-3, 1e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th
td>
#       <td>04:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.895634</td>
#       <td>0.569116</td>
#       <td>0.941209</td>
#       <td>0.980544</td>
#       <td>0.973185</td>
#       <td>0.959037</td>
#       <td>04:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.833233</td>
#       <td>0.535171</td>
#       <td>0.945673</td>
#       <td>0.983340</td>
#       <td>0.972791</td>
#       <td>0.961869</td>
#       <td>04:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.748616</td>
#       <td>0.530204</td>
#       <td>0.945807</td>
#       <td>0.982845</td>
#       <td>0.974797</td>
#       <td>0.962314</td>
#       <td>04:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.697772</td>
#       <td>0.551058</td>
#       <td>0.948019</td>
#       <td>0.984919</td>
#       <td>0.972529</td>
#       <td>0.963372</td>
#       <td>04:15</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='454' class='' max='1255', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.18% [454/1255 01:24<02:28 1.6510]
#     </div>
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
learn.lr_find()

# %%
learn.save('model1')

# %%
learn.recorder.plot_loss()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-a2296441fda2> in <module>
# ----> 1 learn.recorder.plot_loss()
#
# ~/anaconda3/envs/hugo/lib/python3.7/site-packages/fastai2/learner.py in plot_loss(self, skip_start, with_valid)
#     535         if with_valid:
#     536             idx = (np.array(self.iters)<skip_start).sum()
# --> 537             plt.plot(self.iters[idx:], L(self.values[idx:]).itemgot(1), label='valid')
#     538             plt.legend()
#     539
#
# ~/anaconda3/envs/hugo/lib/python3.7/site-packages/fastcore/foundation.py in itemgot(self, *idxs)
#     377     def itemgot(self, *idxs):
#     378         x = self
# --> 379         for idx in idxs: x = x.map(itemgetter(idx))
#     380         return x
#     381
#
# ~/anaconda3/envs/hugo/lib/python3.7/site-packages/fastcore/foundation.py in map(self, f, *args, **kwargs)
#     360              else f.format if isinstance(f,str)
#     361              else f.__getitem__)
# --> 362         return self._new(map(g, self))
#     363
#     364     def filter(self, f, negate=False, **kwargs):
#
# ~/anaconda3/envs/hugo/lib/python3.7/site-packages/fastcore/foundation.py in _new(self, items, *args, **kwargs)
#     313     @property
#     314     def _xtra(self): return None
# --> 315     def _new(self, items, *args, **kwargs): return type(self)(items, *args, use_list=None, **kwargs)
#     316     def __getitem__(self, idx): return self._get(idx) if is_indexer(idx) else L(self._get(idx), use_list=None)
#     317     def copy(self): return self._new(self.items.copy())
#
# ~/anaconda3/envs/hugo/lib/python3.7/site-packages/fastcore/foundation.py in __call__(cls, x, *args, **kwargs)
#      39             return x
#      40
# ---> 41         res = super().__call__(*((x,) + args), **kwargs)
#      42         res._newchk = 0
#      43         return res
#
# ~/anaconda3/envs/hugo/lib/python3.7/site-packages/fastcore/foundation.py in __init__(self, items, use_list, match, *rest)
#     304         if items is None: items = []
#     305         if (use_list is not None) or not _is_array(items):
# --> 306             items = list(items) if use_list else _listify(items)
#     307         if match is not None:
#     308             if is_coll(match): match = len(match)
#
# ~/anaconda3/envs/hugo/lib/python3.7/site-packages/fastcore/foundation.py in _listify(o)
#     240     if isinstance(o, list): return o
#     241     if isinstance(o, str) or _is_array(o): return [o]
# --> 242     if is_iter(o): return list(o)
#     243     return [o]
#     244
#
# ~/anaconda3/envs/hugo/lib/python3.7/site-packages/fastcore/foundation.py in __call__(self, *args, **kwargs)
#     206             if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     207         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 208         return self.fn(*fargs, **kwargs)
#     209
#     210 # Cell
#
# ~/anaconda3/envs/hugo/lib/python3.7/site-packages/fastcore/foundation.py in __getitem__(self, idx)
#     314     def _xtra(self): return None
#     315     def _new(self, items, *args, **kwargs): return type(self)(items, *args, use_list=None, **kwargs)
# --> 316     def __getitem__(self, idx): return self._get(idx) if is_indexer(idx) else L(self._get(idx), use_list=None)
#     317     def copy(self): return self._new(self.items.copy())
#     318
#
# ~/anaconda3/envs/hugo/lib/python3.7/site-packages/fastcore/foundation.py in _get(self, i)
#     318
#     319     def _get(self, i):
# --> 320         if is_indexer(i) or isinstance(i,slice): return getattr(self.items,'iloc',self.items)[i]
#     321         i = mask2idxs(i)
#     322         return (self.items.iloc[list(i)] if hasattr(self.items,'iloc')
#
# IndexError: list index out of range

# %%
learn.fit_one_cycle(10, lr_max=1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>grapheme_root</th>
#       <th>vowel_diacritic</th>
#       <th>consonant_diacritic</th>
#       <th>recall_combine</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.597472</td>
#       <td>0.554701</td>
#       <td>0.949060</td>
#       <td>0.984599</td>
#       <td>0.974368</td>
#       <td>0.964271</td>
#       <td>04:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.600309</td>
#       <td>0.559288</td>
#       <td>0.948261</td>
#       <td>0.985112</td>
#       <td>0.972831</td>
#       <td>0.963616</td>
#       <td>04:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.580440</td>
#       <td>0.582065</td>
#       <td>0.947792</td>
#       <td>0.985537</td>
#       <td>0.974065</td>
#       <td>0.963797</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.600543</td>
#       <td>0.578058</td>
#       <td>0.948058</td>
#       <td>0.985093</td>
#       <td>0.971903</td>
#       <td>0.963278</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.593486</td>
#       <td>0.590464</td>
#       <td>0.947870</td>
#       <td>0.984788</td>
#       <td>0.972165</td>
#       <td>0.963174</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.577622</td>
#       <td>0.579214</td>
#       <td>0.948236</td>
#       <td>0.984175</td>
#       <td>0.972796</td>
#       <td>0.963361</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.556200</td>
#       <td>0.584687</td>
#       <td>0.947478</td>
#       <td>0.984893</td>
#       <td>0.972251</td>
#       <td>0.963025</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.550427</td>
#       <td>0.586769</td>
#       <td>0.947129</td>
#       <td>0.984710</td>
#       <td>0.972128</td>
#       <td>0.962774</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.554244</td>
#       <td>0.590264</td>
#       <td>0.948345</td>
#       <td>0.985277</td>
#       <td>0.972400</td>
#       <td>0.963591</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.552720</td>
#       <td>0.600250</td>
#       <td>0.947630</td>
#       <td>0.984823</td>
#       <td>0.971600</td>
#       <td>0.962921</td>
#       <td>04:19</td>
#     </tr>
#   </tbody>
# </table>
